# %% [markdown]
# <a href="https://colab.research.google.com/github/IGardocki/PythonIntro/blob/main/0_intro_to_python_notebooks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hello!
# Well, hello there, friend! I see you're interested in getting into the world of learning to code in Python, and that's very exciting!
#
# Starting out, this can seem like a very intimidating process, but we're happy to have you here!

# %% [markdown]
# ## What is Python anyway??
#
# Good question! Python is one of the many programming languages out there. A programming language is simply a way of you telling a computer to perform a certain task.
#
# Much like humans have different languages, such as English, Spanish, Mandarin, Polish, German, etc. computers also have different languages! We'll kind of "gloss over" this for now, but, in short, python is probably one of the easiest and most applicable programming languages to learn!
#
# But, before we get into that, let's talk about this weird file we're looking at currently!

# %% [markdown]
# # Sooo, what am I even looking at right now?
#
# You are currently looking at a Jupyter notebook (or .ipynb) file! Specifically, in Google Colab. Jupyter notebooks are GREAT because they allow you to run code blocks, and give you the output of the specific block you ran right then and there!
#
# Those specifics probably aren't important right now, but just know that using them is an easy way to start off coding!

# %% [markdown]
# # Notebook Basics:
#
# So, notebooks have two different types of cells! Text cells (which we have seen so far) allow us to display text! But we also have code cells! What is a code cell? Check out this thing below:

# %%
2+2
# Out:
# 4

# %% [markdown]
# Pretty cool, right? A code cell is basically a cell that tells a computer to run a certain command. In this case, we're telling it to run the calculation 2+2, which we know equals 4!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We input 2+2, and then we get the output of 4. Pretty neat!

# %% [markdown]
# # So, how do you create cells?
# ###Lets start by creating a text cell!
#
# If you put your cursor at the bottom of an existing cell, you'll see two options pop up! They should look like this:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Let's click on the text option for now! You should see something like this appear below the cell you were just working with:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In the left box, start typing stuff! Really anything you feel like. In the right box, it will show how the test will appear in the notebook. When you're done typing, press shift+enter to run the cell.

# %% [markdown]
# Put your cursor at the botom of this text, and create your own text cell!

# %% [markdown]
# That was pretty neat! You just created your first text cell in Colab! Congratulations!!!

# %% [markdown]
# There's some other cool stuff that can happen with text cells. For example, if you type hashtags before your text, it will be different sizes. For example...

# %% [markdown]
# This thing:
#
# # This is a big text with one hashtag
# ## This is a slightly smaller text with two hashtags
# ### This is big, but also smaller than the other two things (3 hashtags)
# #### This is with four hashtags
# ##### This is with 5 hashtags
# ###### This is with 6.
# ####### This is with seven.
#
# And here's normal typing.
#
# You'll notice that after 6 hashtags, it just looks like normal text!

# %% [markdown]
# So, what does the above text look like before I press shift + enter? Well, something like this:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Play around with creating text of different sizes! You'll notice that the fewer hashtags you put in front of text, the larger it is! Next time, we'll start to get into code cells, which are even more important in doing cool stuff with colab!
